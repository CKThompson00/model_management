# %%
import requests
from azure.identity import DefaultAzureCredential

# Replace with your actual subscription ID and location
subscription_id = "4d89db8e-5a7e-4462-af2b-fc9bc225f338"
location = "CentralUS"
api_version = "2024-10-01"

# Construct the endpoint URL
url = f"https://management.azure.com/subscriptions/{subscription_id}/providers/Microsoft.CognitiveServices/locations/{location}/models?api-version={api_version}"

# Authenticate using Azure Identity (requires Azure CLI login or environment credentials)
credential = DefaultAzureCredential()
token = credential.get_token("https://management.azure.com/.default").token

# Set headers
headers = {
    "Authorization": f"Bearer {token}",
    "Content-Type": "application/json"
}

# Make the GET request
response = requests.get(url, headers=headers)

# Check and print results
if response.status_code == 200:
    models = response.json()
    print(models)
    for model in models.get("value", []):
        print(f"Model Name: {model['model']['name']}, Version: {model['model']['version']}, Lifecycle: {model['model']['lifecycleStatus']}, Deprecation Date: {model['model']['deprecation'].get('inference', 'N/A')}   ")
else:
    print(f"Error {response.status_code}: {response.text}")
# Out:
# {'value': [{'id': '/subscriptions/4d89db8e-5a7e-4462-af2b-fc9bc225f338/providers/Microsoft.CognitiveServices/locations/CentralUS/models/AI21 Labs.AI21-Jamba-1.5-Large.1', 'type': 'Microsoft.CognitiveServices/locations/models', 'name': 'AI21 Labs.AI21-Jamba-1.5-Large.1', 'location': 'CentralUS', 'kind': 'MaaS', 'skuName': 'S0', 'model': {'format': 'AI21 Labs', 'name': 'AI21-Jamba-1.5-Large', 'version': '1', 'isDefaultVersion': False, 'skus': [{'name': 'GlobalStandard', 'usageName': 'AIServices.GlobalStandard.MaaS', 'capacity': {'maximum': 1, 'default': 1}}], 'maxCapacity': 3, 'capabilities': {'chatCompletion': 'true'}, 'deprecation': {'inference': '2099-12-31T00:00:00Z'}, 'lifecycleStatus': 'Stable', 'systemData': {'createdBy': 'Microsoft', 'createdByType': 'Application', 'createdAt': '2024-10-01T00:00:00Z', 'lastModifiedBy': 'MaaSModelConverter', 'lastModifiedByType': 'Application', 'lastModifiedAt': '2025-04-16T04:45:33.9367873Z'}}}, {'id': '/subscriptions/4d89db8e-5a7e-4462-af2b-fc9bc225f338/providers/Microsoft.CognitiveServices/locations/CentralUS/models/AI21 Labs.AI21-Jamba-1.5-Mini.1', 'type': 'Microsoft.CognitiveServices/locations/models', 'name': 'AI21 Labs.AI21-Jamba-1.5-Mini.1', 'location': 'CentralUS', 'kind': 'MaaS', 'skuName': 'S0', 'model': {'format': 'AI21 Labs', 'name': 'AI21-Jamba-1.5-Mini', 'version': '1', 'isDefaultVersion': False, 'skus': [{'name': 'GlobalStandard', 'usageName': 'AIServices.GlobalStandard.MaaS', 'capacity': {'maximum': 1, 'default': 1}}], 'maxCapacity': 3, 'capabilities': {'chatCompletion': 'true'}, 'deprecation': {'inference': '2099-12-31T00:00:00Z'}, 'lifecycleStatus': 'Stable', 'systemData': {'createdBy': 'Microsoft', 'createdByType': 'Application', 'createdAt': '2024-10-01T00:00:00Z', 'lastModifiedBy': 'MaaSModelConverter', 'lastModifiedByType': 'Application', 'lastModifiedAt': '2025-04-16T04:45:33.9367873Z'}}}, {'id': '/subscriptions/4d89db8e-5a7e-4462-af2b-fc9bc225f338/providers/Microsoft.CognitiveServices/locations/CentralUS/models/AI21 Labs.AI21-Jamba-Instruct.1', 'type': 'Microsoft.CognitiveServices/locations/models', 'name': 'AI21 Labs.AI21-Jamba-Instruct.1', 'location': 'CentralUS', 'kind': 'MaaS', 'skuName': 'S0', 'model': {'format': 'AI21 Labs', 'name': 'AI21-Jamba-Instruct', 'version': '1', 'isDefaultVersion': False, 'skus': [{'name': 'GlobalStandard', 'usageName': 'AIServices.GlobalStandard.MaaS', 'capacity': {'maximum': 1, 'default': 1}}], 'maxCapacity': 3, 'capabilities': {'chatCompletion': 'true'}, 'deprecation': {'inference': '2099-12-31T00:00:00Z'}, 'lifecycleStatus': 'Stable', 'systemData': {'createdBy': 'Microsoft', 'createdByType': 'Application', 'createdAt': '2024-10-01T00:00:00Z', 'lastModifiedBy': 'MaaSModelConverter', 'lastModifiedByType': 'Application', 'lastModifiedAt': '2025-04-16T04:45:33.9367873Z'}}}, {'id': '/subscriptions/4d89db8e-5a7e-4462-af2b-fc9bc225f338/providers/Microsoft.CognitiveServices/locations/CentralUS/models/Mistral AI.Codestral-2501.2', 'type': 'Microsoft.CognitiveServices/locations/models', 'name': 'Mistral AI.Codestral-2501.2', 'location': 'CentralUS', 'kind': 'MaaS', 'skuName': 'S0', 'model': {'format': 'Mistral AI', 'name': 'Codestral-2501', 'version': '2', 'isDefaultVersion': False, 'skus': [{'name': 'GlobalStandard', 'usageName': 'AIServices.GlobalStandard.MaaS', 'capacity': {'maximum': 1, 'default': 1}}], 'maxCapacity': 3, 'capabilities': {'chatCompletion': 'true'}, 'deprecation': {'inference': '2099-12-31T00:00:00Z'}, 'lifecycleStatus': 'Stable', 'systemData': {'createdBy': 'Microsoft', 'createdByType': 'Application', 'createdAt': '2024-10-01T00:00:00Z', 'lastModifiedBy': 'MaaSModelConverter', 'lastModifiedByType': 'Application', 'lastModifiedAt': '2025-04-16T04:45:33.9367873Z'}}}, {'id': '/subscriptions/4d89db8e-5a7e-4462-af2b-fc9bc225f338/providers/Microsoft.CognitiveServices/locations/CentralUS/models/Cohere.cohere-command-a.1', 'type': 'Microsoft.CognitiveServices/locations/models', 'name': 'Cohere.cohere-command-a.1', 'location':  ...
# Model Name: AI21-Jamba-1.5-Large, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: AI21-Jamba-1.5-Mini, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: AI21-Jamba-Instruct, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Codestral-2501, Version: 2, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: cohere-command-a, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Cohere-command-r, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Cohere-command-r-08-2024, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Cohere-command-r-plus, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Cohere-command-r-plus-08-2024, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Cohere-embed-v3-english, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Cohere-embed-v3-multilingual, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: DeepSeek-R1, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: DeepSeek-R1-0528, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: DeepSeek-V3, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: DeepSeek-V3-0324, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: DeepSeek-V3.1, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: embed-v-4-0, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: jais-30b-chat, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: jais-30b-chat, Version: 2, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: jais-30b-chat, Version: 3, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Llama-3.2-11B-Vision-Instruct, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Llama-3.2-11B-Vision-Instruct, Version: 2, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Llama-3.2-90B-Vision-Instruct, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Llama-3.2-90B-Vision-Instruct, Version: 2, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Llama-3.2-90B-Vision-Instruct, Version: 3, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Llama-3.3-70B-Instruct, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Llama-3.3-70B-Instruct, Version: 2, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Llama-3.3-70B-Instruct, Version: 3, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Llama-3.3-70B-Instruct, Version: 4, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Llama-3.3-70B-Instruct, Version: 5, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: MAI-DS-R1, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Meta-Llama-3-70B-Instruct, Version: 6, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Meta-Llama-3-70B-Instruct, Version: 7, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Meta-Llama-3-70B-Instruct, Version: 8, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Meta-Llama-3-70B-Instruct, Version: 9, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Meta-Llama-3-8B-Instruct, Version: 6, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Meta-Llama-3-8B-Instruct, Version: 7, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Meta-Llama-3-8B-Instruct, Version: 8, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Meta-Llama-3-8B-Instruct, Version: 9, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Meta-Llama-3.1-405B-Instruct, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Meta-Llama-3.1-70B-Instruct, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Meta-Llama-3.1-70B-Instruct, Version: 2, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Meta-Llama-3.1-70B-Instruct, Version: 3, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Meta-Llama-3.1-70B-Instruct, Version: 4, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Meta-Llama-3.1-8B-Instruct, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Meta-Llama-3.1-8B-Instruct, Version: 2, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Meta-Llama-3.1-8B-Instruct, Version: 3, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Meta-Llama-3.1-8B-Instruct, Version: 4, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Meta-Llama-3.1-8B-Instruct, Version: 5, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Ministral-3B, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Mistral-large-2407, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Mistral-Large-2411, Version: 2, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Mistral-Nemo, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Mistral-small, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: mistral-small-2503, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-medium-128k-instruct, Version: 3, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-medium-128k-instruct, Version: 4, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-medium-128k-instruct, Version: 5, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-medium-128k-instruct, Version: 6, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-medium-128k-instruct, Version: 7, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-medium-4k-instruct, Version: 3, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-medium-4k-instruct, Version: 4, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-medium-4k-instruct, Version: 5, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-medium-4k-instruct, Version: 6, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-mini-128k-instruct, Version: 10, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-mini-128k-instruct, Version: 11, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-mini-128k-instruct, Version: 12, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-mini-128k-instruct, Version: 13, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-mini-4k-instruct, Version: 10, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-mini-4k-instruct, Version: 11, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-mini-4k-instruct, Version: 13, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-mini-4k-instruct, Version: 14, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-mini-4k-instruct, Version: 15, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-small-128k-instruct, Version: 3, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-small-128k-instruct, Version: 4, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-small-128k-instruct, Version: 5, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-small-8k-instruct, Version: 3, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-small-8k-instruct, Version: 4, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3-small-8k-instruct, Version: 5, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3.5-mini-instruct, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3.5-mini-instruct, Version: 2, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3.5-mini-instruct, Version: 3, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3.5-mini-instruct, Version: 4, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3.5-mini-instruct, Version: 6, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3.5-MoE-instruct, Version: 2, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3.5-MoE-instruct, Version: 3, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3.5-MoE-instruct, Version: 4, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3.5-MoE-instruct, Version: 5, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3.5-vision-instruct, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-3.5-vision-instruct, Version: 2, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-4, Version: 2, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-4, Version: 3, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-4, Version: 4, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-4, Version: 5, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-4, Version: 6, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-4, Version: 7, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-4-mini-instruct, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-4-multimodal-instruct, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-4-reasoning, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Phi-4-mini-reasoning, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Llama-4-Maverick-17B-128E-Instruct-FP8, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: Llama-4-Scout-17B-16E-Instruct, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: mistral-medium-2505, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: mistral-document-ai-2505, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: grok-3, Version: 1, Lifecycle: Preview, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: grok-3-mini, Version: 1, Lifecycle: Preview, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: FLUX-1.1-pro, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: FLUX.1-Kontext-pro, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z
# Model Name: gpt-oss-120b, Version: 1, Lifecycle: Stable, Deprecation Date: 2099-12-31T00:00:00Z

# %%
import requests
import pyodbc
from azure.identity import DefaultAzureCredential
from dotenv import load_dotenv
import os

load_dotenv()

# === SQL Server Connection ===
server = 'cnt-demo-db-2.database.windows.net'
database = 'demodb'
username = os.getenv("SQL_USERNAME")
password = os.getenv("SQL_PASSWORD")
driver = 'ODBC Driver 17 for SQL Server'

conn_str = f'DRIVER={driver};SERVER={server};DATABASE={database};UID={username};PWD={password}'
conn = pyodbc.connect(conn_str)

# === Azure API Call ===
subscription_id = os.getenv("SUBSCRIPTION_ID")
location = "EastUS"
api_version = "2024-10-01"
url = f"https://management.azure.com/subscriptions/{subscription_id}/providers/Microsoft.CognitiveServices/locations/{location}/models?api-version={api_version}"

credential = DefaultAzureCredential()
token = credential.get_token("https://management.azure.com/.default").token

headers = {
    "Authorization": f"Bearer {token}",
    "Content-Type": "application/json"
}

response = requests.get(url, headers=headers)

cursor = conn.cursor()
# === Upsert Each Model ===
if response.status_code == 200:
    models = response.json().get("value", [])
    for model in models:
        model_name = model['model']['name']
        model_version = model['model']['version']
        lifecycle_status = model['model']['lifecycleStatus']
        deprecation_date = model['model']['deprecation'].get('inference', 'N/A')
        name = model['name']
        location = model['location']
        model_format = model['model']['format']

        cursor.execute(f"""
                MERGE models AS target
                USING (SELECT '{model_name}' AS model_name, '{model_version}' AS model_version, '{lifecycle_status}' AS lifecycle_status, 
                    '{deprecation_date}' AS deprecation_date, '{name}' AS name, '{location}' AS location, '{model_format}' AS model_format) AS source
                ON target.model_name = source.model_name 
                AND target.model_version = source.model_version 
                AND target.lifecycle_status = source.lifecycle_status 
                AND target.deprecation_date = source.deprecation_date
                AND target.location = source.location
                WHEN MATCHED THEN
                    UPDATE SET last_update_date = GETDATE()
                WHEN NOT MATCHED THEN
                    INSERT (name, location, model_name, model_version, lifecycle_status, deprecation_date, model_format)
                    VALUES (source.name, source.location, source.model_name, source.model_version, source.lifecycle_status, source.deprecation_date, source.model_format);
           """)

        conn.commit()
else:
    print(f"Error {response.status_code}: {response.text}")

cursor.close()
conn.close()
